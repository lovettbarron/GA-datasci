# %% [markdown]
# # First go
# This is a first attempt to bring data in and make use of pandas.
#
# The goal is to pull in a data set, and create a few tables based on the data, using the pandas API.

# %%
# Import necessary libraries
from pandas import DataFrame, read_csv
import matplotlib.pyplot as plt
import pandas as pd
import sys

# inline plot
# %matplotlib inline

# %%
d_csv = pd.read_csv("../data/countries.csv")
d_csv.dtypes
# Out:
# ID                    int64
# country              object
# infant_mortality    float64
# gdpcap                int64
# literacy            float64
# dtype: object

# %%
ds = d_csv.sort_values(['gdpcap'],ascending=True)
ds.head(10)
ds['gdpcap'].describe()
# Out:
# count      210.000000
# mean      9820.476190
# std      10197.246545
# min        500.000000
# 25%       1900.000000
# 50%       5700.000000
# 75%      15700.000000
# max      55100.000000
# Name: gdpcap, dtype: float64

# %%
gdp = ds.groupby('gdpcap')
ds.plot(x='gdpcap',y='infant_mortality',figsize=(15,5),kind="scatter")
ds.plot(x='gdpcap',y='literacy',figsize=(15,5),kind="scatter",
       ylim=(0.,1.), subplots=True)
# max_val = ds["gdpcap"].max()
# ds.sort_values(by="gdpcap",ascending=False)
# plt.annotate(xy=(1, max_val), xytext=(8, 0), 
#                  xycoords=('axes fraction', 'data'), textcoords='offset points')
# ds[ds['gdpcap'] == ds['gdpcap'].max()]
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x106d1c850>], dtype=object)
# /Users/albarron/anaconda/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
pd.scatter_matrix(ds,alpha=0.05,figsize=(10,10), diagonal='hist')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x106d9d7d0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x107b56290>]], dtype=object)
