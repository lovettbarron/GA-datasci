# %% [markdown]
# # Attempt 2
# Awesome. I'm going to try and pull in a time-series data set, and identify a trend in the data

# %%
# Import necessary libraries
from pandas import DataFrame, read_csv
import matplotlib.pyplot as plt
import pandas as pd
import sys

# inline plot
# %matplotlib inline

# %% [markdown]
# Pull in the data

# %%
pd.read_csv?
ds = pd.read_csv("../data/income.csv")
ds.columns=['age','employment','income','education','?1','marital','job','cohabitant?','ethnicity','gender','?2','?3','?4','Country of Birth','Income?']
print ds.dtypes
ds.head(10)
# Out:
# age                  int64
# employment          object
# income               int64
# education           object
# ?1                   int64
# marital             object
# job                 object
# cohabitant?         object
# ethnicity           object
# gender              object
# ?2                   int64
# ?3                   int64
# ?4                   int64
# Country of Birth    object
# Income?             object
# dtype: object
#    age         employment  income      education  ?1                 marital  \
# 0   50   Self-emp-not-inc   83311      Bachelors  13      Married-civ-spouse
# 1   38            Private  215646        HS-grad   9                Divorced
# 2   53            Private  234721           11th   7      Married-civ-spouse
# 3   28            Private  338409      Bachelors  13      Married-civ-spouse
# 4   37            Private  284582        Masters  14      Married-civ-spouse
# ...

# %%
pd.scatter_matrix?
pd.scatter_matrix(ds,alpha=0.05,figsize=(20,15), diagonal='hist')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x106b6a9d0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1086424d0>]], dtype=object)
# /Users/albarron/anaconda/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
